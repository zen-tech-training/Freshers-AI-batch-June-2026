# %%
import ollama
from ollama import Client
import os
from dotenv import load_dotenv, find_dotenv

env_path = find_dotenv()
if not env_path:
    raise FileNotFoundError(".env file not found.")

load_dotenv(env_path)
apiKey = os.getenv("OLLAMA_API_KEY")

# %%
#You need the ollama api key if using commercial LLM.. otherwise use gpt-oss:120b-cloud without restriction
#client = Client(host='http://localhost:11434', headers={'x-api-key': 'aaa'})
#response = ollama.chat(xxx)

response = ollama.chat(
    model="gpt-oss:120b-cloud",
    messages=[
        {"role": "user", "content": "Which is the capital city of India?"}
    ]
)
print(response['message']['content'])
